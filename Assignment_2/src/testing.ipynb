# %%
# %load_ext autoreload
# %autoreload 2

# %%
from main import *

# %%
from tqdm import trange

# %%
@jit(nopython=False)
def euler_routine(N, n, dt, D):
    x_list = []
    x = np.zeros(N)
    for i in range(n):
        x = euler_scheme(x, n, dt, D)
        x_list.append(np.average(x))
    return x_list

# %%
# %%time
x_list = []
x = np.zeros(1000)
N = 1000
for n in range(N):
    x = euler_scheme(x, n , 0.001, 0.5)
    x_list.append(np.average(x))
# Out:
# Wall time: 850 ms

# %%
plt.plot(x_list)
