# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
g, p = 3, 3
e, v = np.load(f"solutions/solution_{g}_{p}.npy", allow_pickle=True)
c =np.load(f"solutions/classifications/{g}_{p}.npy")

# %%
e[0]
# Out:
# (238.84027195753424+0j)

# %%
m = int(np.sqrt(v.shape[0]))

# %%
sup = np.ma.array((v[:,3] + v[:,4]).reshape((m,m)), mask = np.invert(c))

# %%
a= np.sort(e/e[0])
e_sorted = np.sort(e)
eff_e = e_sorted[a>=1]

# %%
plt.plot(4*np.pi*np.cumsum(np.sqrt(eff_e)))

# %%
plt.contourf(sup, levels=m)

# %%
N = 100

for i in range(N):
    s = np.ma.array(v[:,i].reshape((m,m)), mask =np.invert(c))
    plt.contourf(s, levels=m)
    plt.show()
