# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %reload_ext autoreload

# %%
from walker import *

# %%
w = Walker()

# %%
w.f(10)

# %%
g = 5
N = 2*4**(g+1)
# %timeit pos = koch_walker(2*N,g)
# Out:
# C:\Users\KarlKristian\Projects\NumFys\Assignment 1\walker.py:54: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "koch_walker" failed type inference due to: non-precise type pyobject
# [1] During: typing of argument at C:\Users\KarlKristian\Projects\NumFys\Assignment 1\walker.py (67)
#
# File "walker.py", line 67:
# def koch_walker(L,depth, i=0, j=0):
#     <source elided>
#     pos_dict = {}
#     for _ in range(4):
#     ^
#
#   @jit
# C:\Users\KarlKristian\Anaconda3\envs\numfys\lib\site-packages\numba\object_mode_passes.py:178: NumbaWarning: Function "koch_walker" was compiled in object mode without forceobj=True.
#
# File "walker.py", line 67:
# def koch_walker(L,depth, i=0, j=0):
#     <source elided>
#     pos_dict = {}
#     for _ in range(4):
#     ^
#
#   state.func_ir.loc))
# C:\Users\KarlKristian\Anaconda3\envs\numfys\lib\site-packages\numba\object_mode_passes.py:187: NumbaDeprecationWarning:
# ...

# %%
N,g
# Out:
# (8192, 5)

# %%
import matplotlib.pyplot as plt

# %%
alist = list(pos)

# %%
fig = plt.figure(figsize = (16,16))
plt.plot(*zip(*alist))
