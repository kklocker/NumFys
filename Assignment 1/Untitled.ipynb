# %%
# %load_ext autoreload
# %autoreload 2

# %%
from grid import *
from walker import *

# %%
import matplotlib.pyplot as plt

# %%
# %%time
g= 4
p_b = 20
lattice = create_lattice(g, points_between=p_b)
m = normalize(lattice)
m
# Out:
# Wall time: 11.2 s
# 8946

# %%
lattice
# Out:
# array([[1785, 1785],
#        [1785, 1786],
#        [1785, 1787],
#        ...,
#        [1788, 1785],
#        [1787, 1785],
#        [1786, 1785]])

# %%
fig = plt.figure(figsize=(16, 16))
plt.plot(*zip(*lattice))
