# %%
# %load_ext autoreload
# %autoreload 2

# %%
from grid import *
from walker import *

# %%
import matplotlib.pyplot as plt

# %%
# %%time
for g in range(5,7):
    for p_b in range(0,5):
        lattice = create_lattice(g, points_between=p_b)
        m = normalize(lattice)
        print(m)
        save_grid(lattice, depth=g, points_between=p_b, max_idx = m)
# Out:
# 1706
# 3412
# 5118
# 6824
# 8530
# 6826
# 13652

# %%
fig = plt.figure(figsize=(16, 16))
plt.plot(*zip(*lattice))
