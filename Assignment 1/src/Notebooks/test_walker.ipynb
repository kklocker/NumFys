# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %reload_ext autoreload

# %%
from walker import *

# %%
w = Walker()

# %%
w.f(10)

# %%
g = 3
N = 2*4**(g+1)
# %time pos = koch_walker(2*N,g)
# Out:
# Wall time: 331 ms

# %%
N,g
# Out:
# (512, 3)

# %%
import matplotlib.pyplot as plt

# %%
alist = list(pos)

# %%
fig = plt.figure(figsize = (10,10))
plt.plot(*zip(*alist))

# %%
pos_2 = list(pos)

# %%
import numpy as np

# %%
nppos = np.array(pos_2)

# %%
nppos[:,0] += np.abs(np.min(nppos[:,0], initial=0))
nppos[:,1] += np.abs(np.min(nppos[:,1], initial=0))

# %%
# Out:
# array([[336, 336],
#        [336, 352],
#        [320, 352],
#        ...,
#        [368, 352],
#        [352, 352],
#        [352, 336]])

# %%
fig = plt.figure(figsize=(10,10))
plt.plot(*zip(*nppos))
